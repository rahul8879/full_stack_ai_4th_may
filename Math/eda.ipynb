# %%
import pandas as pd

data = pd.read_csv('churn_data.csv')
data.head(3)
# Out:
#    Age  MonthlyCharge  Churned
# 0   55          60.30        0
# 1   52          45.55        0
# 2   65          45.59        0

# %%
data['MonthlyCharge'].mean()
# Out:
# np.float64(56.77725)

# %%
# ipykernel
